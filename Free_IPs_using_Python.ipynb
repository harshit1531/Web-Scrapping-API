# %% [markdown]
# <a href="https://colab.research.google.com/github/harshit1531/Web-Scrapping-API/blob/main/Free_IPs_using_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import BeautifulSoup as bs

# %%
def free_proxy():
    url = 'https://free-proxy-list.net/'
    r = requests.get(url)
    soup = bs(r.content,'html.parser')
    proxies = []
    ip_ = []
    td_list = soup.find('table', class_='table-striped').tbody.find_all('tr')
    for row in td_list:
        td = row.find_all('td')
        try:
            ip = td[0].text
            port = td[1].text
            proxies.append(ip + ':' + port)
            ip_.append(ip)
        except:
            continue
    return proxies,ip_

# %%
proxy,ip = free_proxy()

# %%
url = 'http://httpbin.org/ip'
working_proxy = []
for i in range(len(proxy)):
    try:
        response = requests.get(url,proxies = {'http':proxy[i], 'https':proxy[i]}, timeout = 2)
        print(response.json(), ' - working')
        working_proxy.append(ip[i])
    except:
        pass
# Out:
# {'origin': '112.120.37.92'}  - working
# {'origin': '34.66.5.144'}  - working
# {'origin': '49.0.2.242'}  - working
# {'origin': '208.109.32.60'}  - working
# {'origin': '198.13.54.14'}  - working
# {'origin': '157.254.193.139'}  - working
# {'origin': '137.74.65.101'}  - working
# {'origin': 'unknown, 103.253.72.243'}  - working
# {'origin': '168.119.119.107'}  - working
# {'origin': '146.59.243.214'}  - working
# {'origin': '94.198.40.18'}  - working
# {'origin': '34.146.16.157'}  - working
# {'origin': '115.144.102.39'}  - working
# {'origin': '197.255.125.12'}  - working
# {'origin': '8.219.64.236'}  - working
# {'origin': '80.154.30.131'}  - working
# {'origin': '146.59.199.12'}  - working
# {'origin': '10.1.25.1, 113.53.231.133'}  - working
# {'origin': '41.93.71.4'}  - working
# {'origin': '185.233.104.162'}  - working
# {'origin': '95.216.33.21'}  - working
# {'origin': '194.67.91.153'}  - working
# {'origin': '185.162.251.76'}  - working
# {'origin': '213.91.197.85'}  - working
# {'origin': '147.28.184.73'}  - working
# {'origin': '203.198.207.253'}  - working
# {'origin': '10.244.0.1, 52.142.208.138'}  - working
# {'origin': '213.230.127.93'}  - working
# {'origin': '174.70.1.210'}  - working
# {'origin': '143.110.232.177'}  - working
# {'origin': '43.255.113.232'}  - working
# {'origin': '3.218.170.94'}  - working
# {'origin': '54.172.69.57'}  - working
# {'origin': '135.125.216.93'}  - working
# {'origin': '52.24.80.166'}  - working
# {'origin': '155.248.197.241'}  - working
# {'origin': '31.186.239.244'}  - working
# {'origin': '152.32.202.108'}  - working
# {'origin': '71.255.153.116'}  - working
# {'origin': '46.47.197.210'}  - working
# {'origin': '134.122.58.174'}  - working
# {'origin': '221.103.225.78'}  - working
# {'origin': '185.206.134.137'}  - working
# {'origin': '72.52.216.118'}  - working
# {'origin': '155.254.192.216'}  - working
# {'origin': '190.128.222.46'}  - working
# {'origin': '111.251.188.1'}  - working
# {'origin': '36.227.242.100'}  - working
# {'origin': '42.98.75.138'}  - working
# {'origin': '216.137.184.252'}  - working
# {'origin': '212.227.155.59'}  - working
# {'origin': '154.118.228.210'}  - working
# {'origin': '110.164.15.182'}  - working
# {'origin': '80.154.30.131'}  - working
# {'origin': '139.144.180.43'}  - working
# {'origin': '185.15.244.162'}  - working
# {'origin': '103.178.54.45'}  - working
# {'origin': '203.145.94.40'}  - working
# {'origin': '152.69.215.206'}  - working
# {'origin': '89.188.110.196'}  - working
# {'origin': '192.168.184.1, 178.49.14.57'}  - working
# {'origin': '212.182.90.118'}  - working
# {'origin': '180.148.6.83'}  - working
# {'origin': '189.250.93.75'}  - working
# {'origin': '20.116.241.100'}  - working
# {'origin': '80.48.119.28'}  - working
# {'origin': '165.3.122.211'}  - working
# {'origin': '165.154.224.14'}  - working
# {'origin': '152.67.99.80'}  - working
# {'origin': '91.229.114.141'}  - working
# {'origin': '3.13.80.246'}  - working
# {'origin': '34.23.45.223'}  - working
# {'origin': '148.76.97.250'}  - working
# {'origin': '100.125.67.175, 119.8.99.39'}  - working
# {'origin': '18.234.214.51'}  - working
# {'origin': '203.24.92.118'}  - working
# {'origin': '89.58.29.103'}  - working
# {'origin': '34.126.187.77'}  - working
# {'origin': '41.231.54.99'}  - working
# {'origin': '5.154.146.114'}  - working
# {'origin': '172.104.61.127'}  - working
# {'origin': 'unknown, 83.175.157.49'}  - working
# {'origin': '65.108.9.186'}  - working
# {'origin': '113.163.216.208'}  - working
# {'origin': '165.154.236.174'}  - working
# {'origin': '111.251.185.125'}  - working
# {'origin': '111.251.180.242'}  - working
# {'origin': '20.210.113.32'}  - working
# {'origin': '20.24.43.214'}  - working
# {'origin': '45.142.106.133'}  - working
# {'origin': '158.69.128.81'}  - working
# {'origin': '82.117.252.99'}  - working
# {'origin': '80.154.30.131'}  - working
# {'origin': '198.59.191.249'}  - working
# {'origin': '154.113.121.60'}  - working
# {'origin': '45.131.66.221'}  - working
# {'origin': '117.251.103.186'}  - working
# {'origin': '41.93.71.4'}  - working
# {'origin': '201.212.246.120'}  - working
# {'origin': '176.100.13.15'}  - working
# {'origin': '82.79.213.118'}  - working
# {'origin': '139.59.228.95'}  - working
# {'origin': '124.243.11.41'}  - working

# %%
working_proxy
# Out:
# ['112.120.37.92',
#  '34.66.5.144',
#  '49.0.2.242',
#  '208.109.32.60',
#  '198.13.54.14',
#  '157.254.193.139',
#  '137.74.65.101',
#  '103.253.72.243',
#  '168.119.119.107',
#  '146.59.243.214',
#  '94.198.40.18',
#  '34.84.72.91',
#  '115.144.102.39',
#  '197.255.125.12',
#  '8.219.97.248',
#  '80.154.30.180',
#  '146.59.199.12',
#  '113.53.231.133',
#  '41.93.71.12',
#  '185.233.104.162',
#  '95.216.33.21',
#  '194.67.91.153',
#  '185.162.251.76',
#  '213.91.197.85',
#  '147.28.184.73',
#  '203.198.207.253',
#  '13.95.173.197',
#  '213.230.127.93',
#  '174.70.1.210',
#  '143.110.232.177',
#  '43.255.113.232',
#  '3.218.170.94',
#  '54.172.69.57',
#  '135.125.216.93',
#  '52.24.80.166',
#  '155.248.197.241',
#  '31.186.239.246',
#  '152.32.202.108',
#  '71.255.153.117',
#  '46.47.197.210',
#  '134.122.58.174',
#  '212.107.31.118',
#  '185.206.134.137',
#  '72.52.217.188',
#  '155.254.192.216',
#  '190.104.173.62',
#  '111.251.188.1',
#  '114.37.218.211',
#  '42.98.75.138',
#  '216.137.184.253',
#  '212.227.155.59',
#  '154.118.228.212',
#  '110.164.15.182',
#  '80.154.30.163',
#  '139.144.180.43',
#  '185.15.244.162',
#  '47.241.122.19',
#  '203.176.221.40',
#  '152.69.215.206',
#  '89.188.110.196',
#  '178.49.14.57',
#  '212.182.90.118',
#  '45.118.139.196',
#  '189.250.93.75',
#  '20.175.138.183',
#  '80.48.119.28',
#  '165.3.122.211',
#  '165.154.224.14',
#  '152.67.99.80',
#  '91.229.114.141',
#  '3.13.80.246',
#  '34.23.45.223',
#  '148.76.97.250',
#  '119.8.236.97',
#  '18.234.214.51',
#  '203.24.92.118',
#  '89.58.29.103',
#  '34.126.187.77',
#  '41.231.54.99',
#  '156.238.128.236',
#  '172.104.61.127',
#  '83.175.157.49',
#  '65.108.9.181',
#  '113.161.131.43',
#  '165.154.236.174',
#  '111.251.185.125',
#  '111.251.180.242',
#  '20.210.113.32',
#  '20.24.43.214',
#  '45.142.106.133',
#  '158.69.128.81',
#  '82.117.252.100',
#  '80.154.30.177',
#  '198.59.191.234',
#  '154.113.121.60',
#  '45.131.66.221',
#  '117.251.103.186',
#  '41.93.71.15',
#  '201.212.246.120',
#  '176.100.13.15',
#  '82.79.213.118',
#  '139.59.228.95',
#  '124.243.11.41']
